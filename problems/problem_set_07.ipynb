# %% [raw]
# ---
# title: "Problem set 7: Continuous Random Variables. Normal Distribution"
# format:
#   html:
#     toc: true
#     number-sections: true
#     code-fold: true
#     code-summary: "Show Python code"
# ---

# %% [markdown]
# During the seminars, we will work on problems of three different difficulty levels. **Category 1** (<span style="color:#28a745;"><strong>green</strong></span>) contains introductory problems, **Category 2** (<span style="color:#007bff;"><strong>blue</strong></span>) contains standard problems, and **Category 3** (<span style="color:#fd7e14;"><strong>orange</strong></span>) contains the most challenging problems.

# %% [markdown]
# # Category 1

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 1
#
# Let $X$ be a random variable with uniform distribution on the interval $(-2,3)$. Find $\mathbb{P}(X>2\mid X>1)$.
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 2
#
# Consider a normally distributed random variable $Z\sim N(0,1)$.
#
# a) What is $P(Z>1.2)$?
#
# b) What is $P(-1.24\le Z\le 1.86)$?
#
# c) The probability is $0.70$ that $Z$ is less than what number?
#
# d) The probability is $0.60$ that $Z$ is greater than what number?
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 3
#
# Consider a normally distributed random variable $X\sim N(5,4)$.
#
# a) What is $P(X>6.4)$?
#
# b) What is $P(5.8\le X<7.0)$?
#
# c) The probability is $0.05$ that $X$ is in the symmetric interval about the mean between which two numbers?
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 4
#
# Consider a normally distributed random variable $X\sim N(6,25)$. Find the following probabilities:
#
# a) $P(6<X<6.4)$
#
# b) $P(0\le X<8)$
#
# c) $P(-2<X\le 0)$
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 5
#
# The manufacturer of a brand new lithium battery claims that the mean life of a battery is $3800$ hours with a standard deviation of $250$ hours.
#
# a) What percentage of batteries will last for more than $3500$ hours?
#
# b) What percentage of batteries will last for more than $4000$ hours?
#
# c) Batteries which will last for more than $c$ hours constitute more than $\frac{1}{5}$ of the population. Find the maximum possible $c$.
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 6
#
# Consider a normally distributed random variable $X\sim N(\mu,\sigma^2)$. It is known that $P(X\le 66)=0.0359$ and $P(X\ge 66)=0.1151$.
#
# a) Give a clearly-labelled sketch to represent these probabilities on a normal curve.
#
# b) Show that the value of $\sigma$ is $5$.
#
# c) Find $P(69\le X\le 83)$.
# :::

# %% [markdown]
# # Category 2

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 1
#
# Random variable $\xi$ takes values in the interval $(a,b)$, where $-\infty\le a<b\le\infty$, and has density $f(x)$. The function $\varphi(x)$ is strictly monotone and differentiable on $(a,b)$. Moreover $\varphi'(x)\neq0$ in $(a,b)$.
#
# Find the density of the random variable $\eta=\varphi(\xi)$. Find the PDF of $\sqrt{\xi}$, if $\xi$ has an exponential distribution with parameter $\lambda$.
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 2
#
# Let $X$ be a random variable with PDF given by
#
# $$
# f_X(x)=
# \begin{cases}
# c x^2, & |x|\le 1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# a) Find the constant $c$.
#
# b) Find $\mathbb{E}(X)$ and $\mathrm{Var}(X)$.
#
# c) Find the CDF of r.v. $X$.
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 3
#
# Let $X$ be a random variable with PDF given by
#
# $$
# f_X(x)=
# \begin{cases}
# x^2\left(2x+\dfrac32\right), & 0<x\le 1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# If $Y=\dfrac{2}{X+3}$, find $\mathrm{Var}(Y)$.
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 4
#
# The p.d.f. of $Y$ is $g(y)=d\cdot y^{-4}$ for $1<y<\infty$.
#
# a) Find $d$.
#
# b) Find the c.d.f.
#
# c) Find $\mathbb{E}(Y)$.
#
# d) Find $m$ such that $\mathbb{P}(Y>m)=0.5$.
#
# e) Find $\mathbb{P}(Y>\mathbb{E}(Y))$.
# :::

# %% [markdown]
# # Category 3

# %% [markdown]
# ::: {.callout-caution collapse="true"}
# ## Problem 1
#
# The probability density function (PDF) of a distribution $\mathbb{P}$, defined on $(\mathbb{R},\mathcal{B}(\mathbb{R}))$, is given by $p(x)$. Find the corresponding CDF for
#
# a)
# $$
# p(x)=\frac{\theta}{\pi(\theta^2+(x-x_0)^2)}
# $$
#
# (Cauchy distribution with scale parameter $\theta$ and location parameter $x_0$);
#
# b)
# $$
# p(x)=k(x-1)^{k-1}I(1\le x\le 2),\qquad k\in\mathbb{N}.
# $$
# :::

# %% [markdown]
# ::: {.callout-caution collapse="true"}
# ## Problem 2
#
# A sniper in the shooting range shoots at the ``quarter circle'', that is, at the area
#
# $$
# D=\{(x,y):x^2+y^2<1,\ x>0,\ y>0\}.
# $$
#
# The distribution of the hitting probability $\mathbb{P}$ is uniform in the region $D$. In other words, the density of such a distribution is
#
# $$
# p(x,y)=\frac{1}{\pi/4}I((x,y)\in D).
# $$
#
# Find:
#
# a) The CDF and the density of the marginal probability distribution $\mathbb{P}_1$, equal to the projection of $\mathbb{P}$ along the first coordinate;
#
# b) The probability of the sniper hitting the square $[0,3/4]\times[0,3/4]$.
# :::

# %% [markdown]
# ::: {.callout-caution collapse="true"}
# ## Problem 3
#
# Random variable $\xi$ has standard Cauchy distribution. Find the PDF of
#
# a) $\dfrac{\xi^2}{1+\xi^2}$,
#
# b) $\dfrac{1}{\xi}$.
# :::
