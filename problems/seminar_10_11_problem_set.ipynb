# %% [markdown]
# # Problem Set 10--11: Joint Continuous Random Variables
#
# *During the seminars, we will work on problems across three different categories of difficulty, with Category 1 being the easiest and Category 3 the most challenging.*

# %% [markdown]
# ## Category 1

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 1
#
# Let $X$ and $Y$ be two jointly continuous random variables with joint PDF:
#
# $$
# f_{XY}(x,y)=
# \begin{cases}
# x+cy^2, & 0\leq x\leq 1,\; 0\leq y\leq 1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# 1. Find the constant $c$.
# 2. Find $P(0\leq X\leq 0.5,\;0\leq Y\leq 0.5)$.
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 2
#
# The probability density function of a random vector $(\xi,\eta)$ is given by
#
# $$
# p_{\xi,\eta}(x,y)=
# \begin{cases}
# Axy, & (x,y)\in D,\\
# 0, & (x,y)\notin D,
# \end{cases}
# $$
#
# where
#
# $$
# D=\{x\geq0,\;y\geq0,\;x+y\leq2\}.
# $$
#
# Find:
#
# **a)** The value of $A$.
#
# **b)** ${\sf P}((\xi,\eta)\in G)$, where
#
# $$
# G=\{0\leq x\leq1,\;0\leq y\leq1\}.
# $$
#
# **c)** $p_{\xi}(x)$ and $p_{\eta}(y)$. Are $\xi$ and $\eta$ independent random variables?
#
# **d)** ${\sf E}\xi$ and ${\sf E}\eta$.
#
# **e)** ${\sf Var}\xi$ and ${\sf Var}\eta$.
#
# **f)** ${\sf Cov}(\xi,\eta)$ and ${\sf Corr}(\xi,\eta)$.
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 3
#
# Let $X$ and $Y$ be two jointly continuous random variables with joint PDF:
#
# $$
# f_{XY}(x,y)=
# \begin{cases}
# cxy^2, & 0\leq y\leq x\leq 1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# 1. Find the constant $c$.
# 2. Find $R_{XY}$ and show it in the $xy$-plane.
# 3. Find the marginal PDFs, $f_X(x)$ and $f_Y(y)$.
# 4. Find $P\left(Y\leq \dfrac{X}{2}\right)$.
# 5. Find
#
# $$
# P\left(Y\leq \frac{X}{4}\;\middle|\;Y\leq \frac{X}{2}\right).
# $$
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 4
#
# The joint probability density function of the random variables $X$ and $Y$ is given by
#
# $$
# p_{X,Y}(x,y)=
# \begin{cases}
# \dfrac32(x^2+y^2), & 0\leq x\leq1,\;0\leq y\leq1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Find ${\sf cov}(X,Y)$ and ${\sf corr}(X,Y)$.
# :::

# %% [markdown]
# ::: {.callout-tip collapse="true"}
# ## Problem 5
#
# The joint probability density function of the random variables $X$ and $Y$ is given by
#
# $$
# p_{X,Y}(x,y)=
# \begin{cases}
# 4xy, & 0\leq x\leq1,\;0\leq y\leq1,\\
# 0, & \text{otherwise}.
# \end{cases}
# $$
#
# Find ${\sf E}X^2Y$ and ${\sf cov}(X,Y)$.
# :::

# %% [markdown]
# ## Category 2

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 6
#
# Let $\xi_1,\xi_2$ be independent random variables, uniformly distributed on $[0,2]$.
#
# Find
#
# $$
# {\sf P}(1\leq \xi_1\xi_2\leq 2).
# $$
# :::

# %% [markdown]
# ::: {.callout-note collapse="true"}
# ## Problem 7
#
# The joint probability density function of the random variables $X$ and $Y$ is given by
#
# $$
# p_{X,Y}(x,y)=\frac{1}{2\pi}e^{-(x^2+y^2)/2}.
# $$
#
# Find
#
# $$
# {\sf E}\sqrt{X^2+Y^2}.
# $$
# :::

# %% [markdown]
# ## Category 3

# %% [markdown]
# ::: {.callout-caution collapse="true"}
# ## Problem 8
#
# The CDF of a random vector $(\xi,\eta)$ is given by
#
# $$
# F_{\xi,\eta}(x,y)=
# \begin{cases}
# 0, & x\leq0\;\text{or}\;y\leq0,\\
# 1-e^{-x^2}-e^{-2y}+e^{-x^2-2y}, & x\geq0,\;y\geq0.
# \end{cases}
# $$
#
# Find:
#
# **a)** The joint PDF $p_{\xi,\eta}(x,y)$.
#
# **b)** The probabilities
#
# $$
# {\sf P}(-2\leq \xi<2,\;1\leq \eta<3),
# $$
#
# $$
# {\sf P}(\xi\geq0,\;\eta\geq1),
# $$
#
# $$
# {\sf P}(\xi<1,\;\eta\geq2).
# $$
#
# **c)** The CDFs $F_{\xi}$ and $F_{\eta}$.
# :::

# %% [markdown]
# ::: {.callout-caution collapse="true"}
# ## Problem 9
#
# Let the random vector $(X,Y)$ have the following density:
#
# $$
# p_{X,Y}(x,y)=
# \frac{1}{2\pi\sqrt{1-\rho^2}}
# \exp\left(
# -\frac{1}{2(1-\rho^2)}(x^2-2\rho xy+y^2)
# \right).
# $$
#
# Find the covariance matrix of $(X,Y)$ and the distribution of $X$.
# :::
